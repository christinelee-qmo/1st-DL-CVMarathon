# %% [markdown]
# # 動態網頁爬蟲 - API Request
#
# * 了解 API Request 用於動態網頁爬蟲的原理
# * 能夠使用 API Request 撰寫動態網頁爬蟲

# %% [markdown]
# ## 作業目標
#
# * 根據範例的教學，去找出 Dcard 中呼叫的 API 當中，有一個跟「取得所有看板」是哪一個？並且利用 Requests 呼叫。

# %% [markdown]
# * 請附上截圖：_______
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %%
import requests,json

url = 'https://www.dcard.tw/service/api/v2/categorization/countries?country=TW&nsfw=true&noFallback=true'
headers = {
    'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 11_1_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.150 Safari/537.36',
    'pragma': 'no-cache',
    'referer': 'https://www.dcard.tw/forum/all',
    'request-through-cf': 'true',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'cookie': '__cfduid=d5975ad589287fbc94f25245d48689ac61613144095; dcsrd=UeorCdgwAdPFO7lu0Lflz_nm; dcsrd.sig=huId21cdFwXbyPWAbfb3q0qca4Q; ab.storage.userId.7af503ae-0c84-478f-98b0-ecfff5d67750={"g":"729493","c":1613144096470,"l":1613144096470}; ab.storage.deviceId.7af503ae-0c84-478f-98b0-ecfff5d67750={"g":"710e9355-f16b-a1e4-157f-3d2ad0d7a069","c":1613144096472,"l":1613144096472}; G_ENABLED_IDPS=google; dcard=...; dcard.sig=u3MGV9gRuGJ6i795dc92FoJ2W-E; ab.storage.sessionId.7af503ae-0c84-478f-98b0-ecfff5d67750={"g":"e6e7488b-8f13-a025-1db8-28e835c2db4e","e":1613237246200,"c":1613235339846,"l":1613235446200}',
    'accept': '*/*',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'ja,ja-JP;q=0.9,zh-TW;q=0.8,zh;q=0.7,en-US;q=0.6,en;q=0.5,de-DE;q=0.4,de;q=0.3',
    'cache-control':'no-cache'
}

r = requests.get('https://www.dcard.tw/service/api/v2/categorization/countries?country=TW&nsfw=true&noFallback=true', headers=headers)
r
# json.loads(r.text)
# Out:
# <Response [403]>
